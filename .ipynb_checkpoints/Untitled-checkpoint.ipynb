# %%
'''
import data
'''

import pandas as pd

data2016 = pd.read_json("raw/moonboard_problems_setup_2016.json")
data2017 = pd.read_json("raw/moonboard_problems_setup_master2017.json")

# %%
data2016
# Out:
#                                                                      341208  \
# Method                                                    Feet follow hands
# Name                                                       OFF THE MATTRESS
# Grade                                                                   8A+
# MoonBoardConfigurationId                                                  0
# Setter                    {'Nickname': 'bcy', 'Firstname': 'Bocheng', 'L...
# Rating                                                                    0
# Repeats                                                                   0
# Holdsetup                 {'Id': 1, 'Description': 'MoonBoard 2016', 'Ho...
# IsBenchmark                                                           False
# IsAssessmentProblem                                                   False
# Moves                     [{'Id': 1910055, 'Description': 'K18', 'IsStar...
# DateInserted                                          /Date(1554298797933)/
#
#                                                                      341206  \
# Method                                                    Feet follow hands
# Name                                                                  COCO2
# Grade                                                                   6B+
# MoonBoardConfigurationId                                                  0
# Setter                    {'Nickname': 'coco', 'Firstname': 'Constantin'...
# Rating                                                                    0
# Repeats                                                                   0
# Holdsetup                 {'Id': 1, 'Description': 'MoonBoard 2016', 'Ho...
# IsBenchmark                                                           False
# IsAssessmentProblem                                                   False
# Moves                     [{'Id': 1910040, 'Description': 'F5', 'IsStart...
# DateInserted                                          /Date(1554297073457)/
#
#                                                                      341205  \
# Method                                                    Feet follow hands
# Name                                                          EASIEST (6A+)
# Grade                                                                   6B+
# MoonBoardConfigurationId                                                  0
# Setter                    {'Nickname': 'Eršketas', 'Firstname': 'Rokas',...
# Rating                                                                    0
# Repeats                                                                   0
# Holdsetup                 {'Id': 1, 'Description': 'MoonBoard 2016', 'Ho...
# IsBenchmark                                                           False
# IsAssessmentProblem                                                   False
# Moves                     [{'Id': 1910030, 'Description': 'F5', 'IsStart...
# DateInserted                                          /Date(1554296922380)/
#
#                                                                      341204  \
# Method                                                    Feet follow hands
# Name                                                                  COCO1
# Grade                                                                   6B+
# MoonBoardConfigurationId                                                  0
# Setter                    {'Nickname': 'coco', 'Firstname': 'Constantin'...
# Rating                                                                    0
# Repeats                                                                   0
# Holdsetup                 {'Id': 1, 'Description': 'MoonBoard 2016', 'Ho...
# IsBenchmark                                                           False
# IsAssessmentProblem                                                   False
# Moves                     [{'Id': 1910021, 'Description': 'F5', 'IsStart...
# DateInserted                                          /Date(1554296909883)/
#
#                                                                      341199  \
# Method                                                    Feet follow hands
# Name                                                             GETGOING()
# Grade                                                                    6C
# MoonBoardConfigurationId                                                  0
# Setter                    {'Nickname': 'BanKiMoon', 'Firstname': 'KiMoon...
# Rating                                                                    0
# Repeats                                                                   0
# Holdsetup                 {'Id': 1, 'Description': 'MoonBoard 2016', 'Ho...
# IsBenchmark                                                           False
# IsAssessmentProblem                                                   False
# Moves                     [{'Id': 1909973, 'Description': 'F5', 'IsStart...
# DateInserted                                          /Date(1554289509533)/
#
#                                                                      341198  \
# Method                                                    Feet follow hands
# Name                                                                GRANERO
# Grade                                                                   6B+
# MoonBoardConfigurationId                                                  0
# Setter                    {'Nickname': 'Karlos', 'Firstname': 'Karlos', ...
# Rating                                                                    0
# Repeats                                                                   0
# Holdsetup                 {'Id': 1, 'Description': 'MoonBoard 2016', 'Ho...
# IsBenchmark                                                           False
# IsAssessmentProblem                                                   False
# Moves                     [{'Id': 1909966, 'Description': 'K5', 'IsStart...
# DateInserted                                          /Date(1554288099717)/
#
#                                                                      341197  \
# Method                                                    Feet follow hands
# Name                                                             BROKEN TOY
# Grade                                                                   7A+
# MoonBoardConfigurationId                                                  0
# Setter                    {'Nickname': 'Mario Irvin', 'Firstname': 'Mari...
# Rating                                                                    0
# Repeats                                                                   1
# Holdsetup                 {'Id': 1, 'Description': 'MoonBoard 2016', 'Ho...
# IsBenchmark                                                           False
# IsAssessmentProblem                                                   False
# Moves                     [{'Id': 1909961, 'Description': 'D3', 'IsStart...
# DateInserted                                          /Date(1554284433083)/
#
#                                                                      341196  \
# Method                                                    Feet follow hands
# Name                                                             WEEDWACKER
# Grade                                                                    7C
# MoonBoardConfigurationId                                                  0
# Setter                    {'Nickname': 'Nemo', 'Firstname': 'Nemo', 'Las...
# Rating                                                                    0
# Repeats                                                                   0
# Holdsetup                 {'Id': 1, 'Description': 'MoonBoard 2016', 'Ho...
# IsBenchmark                                                           False
# IsAssessmentProblem                                                   False
# Moves                     [{'Id': 1909956, 'Description': 'K5', 'IsStart...
# DateInserted                                          /Date(1554283366490)/
#
#                                                                      341195  \
# Method                                                    Feet follow hands
# Name                                                               SHOUSING
# Grade                                                                   6B+
# MoonBoardConfigurationId                                                  0
# Setter                    {'Nickname': 'Matthew Doyle', 'Firstname': 'Ma...
# Rating                                                                    0
# Repeats                                                                   1
# Holdsetup                 {'Id': 1, 'Description': 'MoonBoard 2016', 'Ho...
# IsBenchmark                                                           False
# IsAssessmentProblem                                                   False
# Moves                     [{'Id': 1909948, 'Description': 'F5', 'IsStart...
# DateInserted                                          /Date(1554278147393)/
#
#                                                                      341194  \
# Method                                                    Feet follow hands
# Name                                                               AL BAGNO
# Grade                                                                   6C+
# MoonBoardConfigurationId                                                  0
# Setter                    {'Nickname': 'Cinghiale ', 'Firstname': 'Anton...
# Rating                                                                    0
# Repeats                                                                   0
# Holdsetup                 {'Id': 1, 'Description': 'MoonBoard 2016', 'Ho...
# IsBenchmark                                                           False
# IsAssessmentProblem                                                   False
# Moves                     [{'Id': 1909940, 'Description': 'D3', 'IsStart...
# DateInserted                                          /Date(1554272976953)/
#
#                           ...  \
# Method                    ...
# Name                      ...
# Grade                     ...
# MoonBoardConfigurationId  ...
# Setter                    ...
# Rating                    ...
# Repeats                   ...
# Holdsetup                 ...
# IsBenchmark               ...
# IsAssessmentProblem       ...
# Moves                     ...
# DateInserted              ...
#
#                                                                      19224   \
# Method                                                    Feet follow hands
# Name                                                                   TESS
# Grade                                                                   6C+
# MoonBoardConfigurationId                                                  0
# Setter                    {'Nickname': 'Ben Moon', 'Firstname': 'Ben', '...
# Rating                                                                    0
# Repeats                                                                3270
# Holdsetup                 {'Id': 1, 'Description': 'MoonBoard 2016', 'Ho...
# IsBenchmark                                                            True
# IsAssessmentProblem                                                   False
# Moves                     [{'Id': 1518065, 'Description': 'F5', 'IsStart...
# DateInserted                                          /Date(1456826415000)/
#
#                                                                      19223   \
# Method                                                    Feet follow hands
# Name                                                              PROBLEM 9
# Grade                                                                   7A+
# MoonBoardConfigurationId                                                  0
# Setter                    {'Nickname': 'Ally Patrick', 'Firstname': 'Ali...
# Rating                                                                    0
# Repeats                                                                 899
# Holdsetup                 {'Id': 1, 'Description': 'MoonBoard 2016', 'Ho...
# IsBenchmark                                                            True
# IsAssessmentProblem                                                   False
# Moves                     [{'Id': 1518059, 'Description': 'J5', 'IsStart...
# DateInserted                                          /Date(1456826415000)/
#
#                                                                      19222   \
# Method                                                    Feet follow hands
# Name                                                                   VURT
# Grade                                                                    7B
# MoonBoardConfigurationId                                                  0
# Setter                    {'Nickname': 'Ben Moon', 'Firstname': 'Ben', '...
# Rating                                                                    0
# Repeats                                                                 475
# Holdsetup                 {'Id': 1, 'Description': 'MoonBoard 2016', 'Ho...
# IsBenchmark                                                            True
# IsAssessmentProblem                                                   False
# Moves                     [{'Id': 1518053, 'Description': 'B3', 'IsStart...
# DateInserted                                          /Date(1456826415000)/
#
#                                                                      19221   \
# Method                                                    Feet follow hands
# Name                                                             SHORTROUND
# Grade                                                                   6C+
# MoonBoardConfigurationId                                                  0
# Setter                    {'Nickname': 'Ally Patrick', 'Firstname': 'Ali...
# Rating                                                                    0
# Repeats                                                                 238
# Holdsetup                 {'Id': 1, 'Description': 'MoonBoard 2016', 'Ho...
# IsBenchmark                                                           False
# IsAssessmentProblem                                                   False
# Moves                     [{'Id': 1518045, 'Description': 'D3', 'IsStart...
# DateInserted                                          /Date(1456826427000)/
#
#                                                                      19220   \
# Method                                                    Feet follow hands
# Name                                                   CRIME AND PUNISHMENT
# Grade                                                                    7B
# MoonBoardConfigurationId                                                  0
# Setter                    {'Nickname': 'Ben Moon', 'Firstname': 'Ben', '...
# Rating                                                                    0
# Repeats                                                                 141
# Holdsetup                 {'Id': 1, 'Description': 'MoonBoard 2016', 'Ho...
# IsBenchmark                                                            True
# IsAssessmentProblem                                                   False
# Moves                     [{'Id': 1518038, 'Description': 'D3', 'IsStart...
# DateInserted                                          /Date(1456826415000)/
#
#                                                                      19219   \
# Method                                                    Feet follow hands
# Name                                                              PROBLEM 5
# Grade                                                                    7A
# MoonBoardConfigurationId                                                  0
# Setter                    {'Nickname': 'Ally Patrick', 'Firstname': 'Ali...
# Rating                                                                    0
# Repeats                                                                  60
# Holdsetup                 {'Id': 1, 'Description': 'MoonBoard 2016', 'Ho...
# IsBenchmark                                                           False
# IsAssessmentProblem                                                   False
# Moves                     [{'Id': 1518030, 'Description': 'C5', 'IsStart...
# DateInserted                                          /Date(1456826415000)/
#
#                                                                      19218   \
# Method                                                    Feet follow hands
# Name                                                             HARD TIMES
# Grade                                                                    7A
# MoonBoardConfigurationId                                                  0
# Setter                    {'Nickname': 'Ben Moon', 'Firstname': 'Ben', '...
# Rating                                                                    0
# Repeats                                                                3312
# Holdsetup                 {'Id': 1, 'Description': 'MoonBoard 2016', 'Ho...
# IsBenchmark                                                            True
# IsAssessmentProblem                                                   False
# Moves                     [{'Id': 1844764, 'Description': 'B10', 'IsStar...
# DateInserted                                          /Date(1456826415000)/
#
#                                                                      19217   \
# Method                                                    Feet follow hands
# Name                                                              PROBLEM 3
# Grade                                                                   6B+
# MoonBoardConfigurationId                                                  0
# Setter                    {'Nickname': 'Ally Patrick', 'Firstname': 'Ali...
# Rating                                                                    0
# Repeats                                                                 129
# Holdsetup                 {'Id': 1, 'Description': 'MoonBoard 2016', 'Ho...
# IsBenchmark                                                           False
# IsAssessmentProblem                                                   False
# Moves                     [{'Id': 1518015, 'Description': 'F5', 'IsStart...
# DateInserted                                          /Date(1456826416000)/
#
#                                                                      19216   \
# Method                                                    Feet follow hands
# Name                                                      WUTHERING HEIGHTS
# Grade                                                                   6B+
# MoonBoardConfigurationId                                                  0
# Setter                    {'Nickname': 'Ben Moon', 'Firstname': 'Ben', '...
# Rating                                                                    0
# Repeats                                                                9138
# Holdsetup                 {'Id': 1, 'Description': 'MoonBoard 2016', 'Ho...
# IsBenchmark                                                            True
# IsAssessmentProblem                                                   False
# Moves                     [{'Id': 1518007, 'Description': 'F5', 'IsStart...
# DateInserted                                          /Date(1456826427000)/
#
#                                                                      19215
# Method                                                    Feet follow hands
# Name                                             FAR FROM THE MADDING CROWD
# Grade                                                                   6B+
# MoonBoardConfigurationId                                                  0
# Setter                    {'Nickname': 'Ben Moon', 'Firstname': 'Ben', '...
# Rating                                                                    0
# Repeats                                                                7228
# Holdsetup                 {'Id': 1, 'Description': 'MoonBoard 2016', 'Ho...
# IsBenchmark                                                            True
# IsAssessmentProblem                                                   False
# Moves                     [{'Id': 1518000, 'Description': 'E6', 'IsStart...
# DateInserted                                          /Date(1456826427000)/
#
# [12 rows x 25907 columns]

# %%
'''
Clean data for 2016 as we have more data for it.
We see that we have 12 rows and are only interested in grade and moves
Note that we must check homogenity across other parameters.
'''
print("Size of Datas")
print(data2016.shape)
print(data2017.shape)

print("Row labels")
print(data2016.index.values)
# Out:
# Size of Datas
# (12, 25907)
# (12, 19885)
# Row labels
# ['Method' 'Name' 'Grade' 'MoonBoardConfigurationId' 'Setter' 'Rating'
#  'Repeats' 'Holdsetup' 'IsBenchmark' 'IsAssessmentProblem' 'Moves'
#  'DateInserted']
